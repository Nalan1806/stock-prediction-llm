# %% [markdown]
# # Module 1 No Code/Low Code Assignment: Stock Price Prediction with LLM (Using Gemini in Colab)
#
# This assignment explores how large language models (LLMs) can perform complex tasks that previously required coding. Instead of manually writing code, we will interact with Google's Gemini (Click on the Gemini icon on the top right corner) in Google Colab to:
#
# - Load and analyze stock price data.
# - Engineer relevant features for prediction.
# - Build and evaluate models such as regression and random forest.
# - Discuss potential trading strategies based on predictions.
#
# **Note**: While this notebook contains example code, students are encouraged to use LLMs to generate code snippets and explanations, managing interactions within the LLM's context window.
#
# ## Task Breakdown
#
# ### Step 1: Data Exploration
# - **Prompt the LLM**: Load historical stock price data for Apple Inc. (AAPL) from 2020-01-01 to 2023-01-01 using Yahoo Finance.
# - **Key Considerations**: Ensure the model retains context while summarizing key statistics.
#
# ### Step 2: Feature Engineering
# - **Prompt the LLM**: Generate meaningful features such as moving averages, technical indicators, and volatility measures.
# - **Managing Context**: If the LLM forgets prior outputs, remind it by reintroducing key statistics.
#
# ### Step 3: Model Building
# - **Prompt the LLM**: Train a model (regression for price prediction, random forest for trend classification).
# - **Split Ratio Consideration**: Explain the importance of train-test split (e.g., 70/30) and verify the LLM respects it.
#
# ### Step 4: Model Evaluation & Prediction
# - **Prompt the LLM**: Use the trained model to predict stock prices for 2023-2024.
# - **Analyze Performance**: Interpret accuracy, R² scores, and classification reports.
#
# ### Step 5: Strategy Discussion
# - **Prompt the LLM**: Based on model performance, discuss possible trading strategies.
# - **Critical Thinking**: Evaluate whether the model is truly useful for financial decision-making.
#
# ---
#
# Throughout the assignment, keep in mind that LLMs have a limited context window. If necessary, break down tasks into smaller chunks and reintroduce critical information.

# %% [markdown]
# ## Using Gemini in Colab
#
# To use Gemini directly in your browser within Google Colab:
#
# 1. **Create a new code cell** by clicking the `+ Code` button.
# 2. In the newly created cell, you will see a placeholder text: **"Start coding or generate with AI"**.
# 3. Click on **"Generate"** and enter your prompt, such as:
#    > "Load historical stock price data for Apple Inc. (AAPL) from 2020-01-01 to 2023-01-01 using Yahoo Finance and summarize its key statistics."
# 4. Gemini will generate code based on your prompt. You can then review, modify, and run it within the notebook.
# 5. If the model loses context, you may need to remind it of previous responses or break down tasks into smaller steps.
#
# This method allows you to interactively generate and refine code without manually writing every line.

# %%
# prompt: Load historical stock price data for Apple Inc. (AAPL) from 2020-01-01 to 2023-01-01 using Yahoo Finance and summarize its key statistics.

# !pip install yfinance

import yfinance as yf
import pandas as pd

# Download historical data for AAPL
data = yf.download("AAPL", start="2020-01-01", end="2023-01-01")

# Display summary statistics
print(data.describe())

# %%
# prompt: Load historical stock price data for Apple Inc. (AAPL) from 2020-01-01 to 2023-01-01 using Yahoo Finance and summarize its key statistics.

# !pip install yfinance

import yfinance as yf
import pandas as pd

# Download historical data for AAPL from 2020-01-01 to 2023-01-01
data = yf.download("AAPL", start="2020-01-01", end="2023-01-01")

# Summarize key statistics
print(data.describe())
# Out:
# ...
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price        Close        High         Low        Open        Volume
# Ticker        AAPL        AAPL        AAPL        AAPL          AAPL
# count   756.000000  756.000000  756.000000  756.000000  7.560000e+02
# mean    127.800474  129.350921  126.136626  127.722421  1.120920e+08
# std      30.461355   30.739156   30.179073   30.489492  5.602586e+07
# min      54.449894   55.452160   51.595990   55.350235  3.519590e+07
# 25%     112.857315  114.354702  111.397715  113.037711  7.636470e+07
# 50%     133.185188  134.319768  131.222483  133.006499  9.493580e+07
# 75%     148.415882  149.584513  146.468716  147.782312  1.296327e+08
# max     178.879913  179.793905  176.039592  179.489238  4.265100e+08

# %%
# Prompt: Load historical stock price data for Apple Inc. (AAPL) from 2020-01-01 to 2023-01-01
# using Yahoo Finance and summarize its key statistics.

import yfinance as yf

data = yf.download("AAPL", start="2020-01-01", end="2023-01-01")

# Summarize key statistics
print(data.describe())
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price        Close        High         Low        Open        Volume
# Ticker        AAPL        AAPL        AAPL        AAPL          AAPL
# count   756.000000  756.000000  756.000000  756.000000  7.560000e+02
# mean    127.800473  129.350921  126.136626  127.722421  1.120920e+08
# std      30.461355   30.739156   30.179073   30.489492  5.602586e+07
# min      54.449894   55.452160   51.595990   55.350235  3.519590e+07
# 25%     112.857307  114.354706  111.397708  113.037705  7.636470e+07
# 50%     133.185196  134.319791  131.222513  133.006484  9.493580e+07
# 75%     148.415874  149.584494  146.468701  147.782328  1.296327e+08
# max     178.879898  179.793936  176.039622  179.489269  4.265100e+08

# %% [markdown]
# ## Now try doing step 2 - step 5 by yourself
#
# The sample prompts and LLM responses are listed below for your reference.

# %% [markdown]
# # Sample Prompts and LLM Responses
# ---
#
# ## Step 1: Data Exploration
#
# ### Prompt:
# > Load historical stock price data for Apple Inc. (AAPL) from 2020-01-01 to 2023-01-01 from Yahoo Finance, keep it in memory and summarize its key statistics.
#
# ### LLM Response:
# - **Highest Closing Price:** \$182.01 on January 3, 2022
# - **Lowest Closing Price:** \$56.01 on March 23, 2020
# - **Average Closing Price:** \$126.69
# - **Total Trading Days:** 756
#
# ---
#
# ## Step 2: Feature Engineering
#
# ### Prompt:
# > Suggest some features that might help improve a stock price prediction model.
#
# ### LLM Response:
# 1. **Historical Prices**: Include past closing, opening, high, and low prices.
# 2. **Volume**: Daily trading volumes.
# 3. **Moving Averages**: Simple and exponential moving averages (e.g., 5-day, 10-day, 50-day).
# 4. **Technical Indicators**: RSI, MACD, Bollinger Bands, etc.
# 5. **Volatility**: Historical volatility, Average True Range (ATR).
# 6. **Sentiment Analysis**: News articles, social media sentiment.
# 7. **Economic Indicators**: Interest rates, inflation rates, GDP growth.
# 8. **Time-based Features**: Day of the week, month, year.
# 9. **Sector Performance**: Comparison with industry and sector indices.
# 10. **External Events**: Major geopolitical events, earnings reports.
#
# ---
#
# ## Step 3.1: Model Building - Linear Regression
#
# ### Prompt:
# > Adopt the first four kinds of features and train a regression model to predict tomorrow's stock price. Split your training and testing data by a 70/30 ratio and report your performance metric.
#
# ### LLM Response:
# - **Mean Squared Error (MSE):** 859.04
# - **R-squared (R²) Score:** -0.009
#
# These metrics indicate that the model is not performing well, as an R² score close to zero or negative suggests that the model does not explain the variability in the target variable better than a simple mean of the target variable. This outcome suggests that the chosen features and model might need adjustments or improvements to enhance prediction accuracy. ​​
#
# ---
# (It might be too hard to predict the exact price but how about ups and downs?)
# # Step 3.2: Model Building - Random Forest Classification
#
# ### Prompt:
# > Create a binary target variable based on historical prices (1 if the close price increase tomorrow, 0 other), and train a Random Forest model using the same train/test split ratio. Report feature importance and performance metrics.
#
# ### LLM Response:
# - **Accuracy:** 71.82%
# - **Confusion Matrix:** [[84, 26],
#  [36, 74]]
# - **Classification Report:**
#
#               precision    recall  f1-score   support
#
#          0       0.70      0.76      0.73       110
#          1       0.74      0.67      0.70       110
#         accuracy                     0.72       220
#         macro avg    0.72      0.72      0.72       220
#         weighted avg  0.72      0.72      0.72       220
#
#
#
# - **Feature Importance:** The most important feature for predicting whether the price will increase or decrease the next day is the closing price, followed by the 5-day moving average (MA_5). The model achieved an accuracy of approximately 71.82%, indicating a reasonable performance for this classification task.
#          Feature	Importance
#          Open	   0.0900
#          High	   0.0883
#          Low	   0.0980
#          Close	   0.3087
#          Volume	    0.0982
#          MA_5	   0.1242
#          MA_10	   0.0974
#          MA_50	   0.0951
#
# ---
#
# ## Step 4: Model Evaluation & Prediction
# ### Prompt:
# > Use this model to predict stock price increase/decrease for period starting from 2023-01-01 to 2024-01-01. Report your performance metrics.
#
# ### LLM Response:
# The Random Forest classifier's performance on the new test data from 2023-01-01 to 2024-01-01 is as follows:
# - **Accuracy:** 60.85%
# - **Confusion Matrix:** [[105,   0],
#  [ 83,  24]]
# - **Classification Report:**
#
#             precision    recall  f1-score   support
#
#        0       0.56      1.00      0.72       105
#        1       1.00      0.22      0.37       107
#
#         accuracy                   0.61       212
#         macro avg  0.78     0.61       0.54       212
#         weighted avg 0.78    0.61        0.54       212
#
# ---
# ## Step 5: Strategy Discussion
# ### Prompt:
# > What do you think about the performance of the model and what trading strategies could I build with this model?
#
# ### LLM Response:
# - The model shows a moderate performance with an accuracy of approximately 60.85%. However, the precision and recall metrics indicate that while the model is good at identifying days when the stock price does not increase (class 0), it struggles significantly to identify days when the stock price does increase (class 1). This suggests a need for further feature engineering or model tuning to improve the prediction performance for this specific classification task.
# - Potential Trading Strategies
# Given the model's performance, potential trading strategies could be formulated as follows:
#
# #### Conservative Strategy:
#
# - **Focus**: Only trade on days when the model predicts a price increase with high confidence.
# - **Action**: Buy stocks when the model predicts an increase (class 1).
# - **Risk Management**: Since the model has a high precision for the no-increase class (class 0), it might be more reliable to stay out of the market when the model predicts no increase.
#
# #### Contrarian Strategy:
#
# - **Focus**: Take advantage of the model's high recall for no price increase predictions (class 0).
# - **Action**: Sell short or avoid buying stocks on days when the model predicts no increase.
# - **Risk Management**: This strategy assumes that the model’s predictions of no price increase are more reliable. It requires a careful assessment of market conditions to avoid false signals.
#
# #### Hybrid Strategy:
#
# - **Combine**: Use both conservative and contrarian strategies based on confidence thresholds.
# - **Action**: Set a higher threshold for buying (only buy when the predicted probability of price increase is significantly high) and a lower threshold for selling or staying out of the market.
# - **Risk Management**: Adjust thresholds dynamically based on recent model performance and market volatility.
#
#
# ---
# ## Conclusion
#
# Through this assignment, we have explored how LLMs can assist in complex machine learning tasks without requiring extensive coding knowledge. Key takeaways:
#
# - **Context Management**: LLMs have limited memory, so breaking tasks into smaller steps and reinforcing context is crucial.
# - **Feature Engineering with LLMs**: The model can suggest features but needs guidance on financial relevance.
# - **Modeling with LLMs**: LLMs can write and refine code, but human judgment is necessary to validate results.
# - **Real-world Limitations**: Stock price prediction remains challenging; models should be used critically and not solely relied upon for trading decisions.
#
# Next Steps:
# - Experiment with different LLMs and compare outputs.
# - Try refining feature engineering techniques.
# - Test alternative modeling approaches, such as deep learning or ensemble methods.

# %%
import yfinance as yf
import pandas as pd

# Download historical data for AAPL
data = yf.download("AAPL", start="2020-01-01", end="2025-01-01")

# Calculate Daily Return
data[('Price', 'Daily Return')] = data[('Price', 'Close')].pct_change()

# Calculate Cumulative Return
data[('Price', 'Cumulative Return')] = (1 + data[('Price', 'Daily Return')]).cumprod() - 1

# Calculate VWAP
data[('Price', 'VWAP')] = (data[('Price', 'Close')] * data[('Volume', 'Volume')]).cumsum() / data[('Volume', 'Volume')].cumsum()


# Summarize key statistics for specified columns
print("Basic Statistics:")
print(data[[('Price', 'Open'), ('Price', 'Close'), ('Price', 'High'), ('Price', 'Low'), ('Volume', 'Volume')]].agg(['mean', 'median', 'min', 'max', 'std']))

print("\nAdditional Statistics:")
print(data[[('Price', 'Daily Return'), ('Price', 'Cumulative Return'), ('Price', 'VWAP')]].agg(['mean', 'median', 'min', 'max', 'std']).dropna())
# Out:
# /tmp/ipython-input-4022487716.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start="2020-01-01", end="2025-01-01")
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# ...

# %%
import yfinance as yf
import pandas as pd

# Download historical data for AAPL
data = yf.download("AAPL", start="2020-01-01", end="2025-01-01")

# Display the first few rows and the columns to understand the structure
print("Data Head:")
display(data.head())
print("\nData Columns:")
print(data.columns)

# Summarize key statistics for relevant columns
print("\nBasic Statistics:")
# Access columns using the correct MultiIndex tuples
print(data[[('Open', 'AAPL'), ('High', 'AAPL'), ('Low', 'AAPL'), ('Close', 'AAPL'), ('Volume', 'AAPL')]].agg(['mean', 'median', 'min', 'max', 'std']))
# Out:
# /tmp/ipython-input-3767118154.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start="2020-01-01", end="2025-01-01")
# [*********************100%***********************]  1 of 1 completed
# Data Head:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.620850  72.681296  71.373226  71.627100  135480400
# 2020-01-03  71.914825  72.676454  71.689965  71.847125  146322800
# 2020-01-06  72.487854  72.526541  70.783256  71.034717  118387200
# 2020-01-07  72.146935  72.753816  71.926907  72.497522  108872000
# 2020-01-08  73.307510  73.609745  71.849533  71.849533  132079200
# Data Columns:
# MultiIndex([( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL')],
#            names=['Price', 'Ticker'])
#
# ...

# %%
# Calculate Technical Indicators

# Relative Strength Index (RSI)
def calculate_rsi(data, window=14):
    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).fillna(0)
    loss = (-delta.where(delta < 0, 0)).fillna(0)
    avg_gain = gain.ewm(com=window-1, adjust=False).mean()
    avg_loss = loss.ewm(com=window-1, adjust=False).mean()
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

data['RSI'] = calculate_rsi(data)

# Moving Average Convergence Divergence (MACD)
exp1 = data['Close'].ewm(span=12, adjust=False).mean()
exp2 = data['Close'].ewm(span=26, adjust=False).mean()
data['MACD'] = exp1 - exp2
data['Signal Line'] = data['MACD'].ewm(span=9, adjust=False).mean()

# Bollinger Bands
window = 20
data['Rolling Mean'] = data['Close'].rolling(window=window).mean()
data['Rolling Std'] = data['Close'].rolling(window=window).std()
data['Upper Band'] = data['Rolling Mean'] + (data['Rolling Std'] * 2)
data['Lower Band'] = data['Rolling Mean'] - (data['Rolling Std'] * 2)


# Calculate Volatility Measures

# Average True Range (ATR)
def calculate_atr(data, window=14):
    high_low = data['High'] - data['Low']
    high_close = abs(data['High'] - data['Close'].shift())
    low_close = abs(data['Low'] - data['Close'].shift())
    ranges = pd.concat([high_low, high_close, low_close], axis=1)
    true_range = ranges.max(axis=1)
    atr = true_range.ewm(com=window-1, adjust=False).mean()
    return atr

data['ATR'] = calculate_atr(data)

# Display the data with the new feature columns
print("Data with Technical Indicators and Volatility Measures:")
display(data.tail())
# Out:
# Data with Technical Indicators and Volatility Measures:
# Price            Close        High         Low        Open    Volume  \
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-12-24  257.578674  257.588630  254.675658  254.875189  23234700
# 2024-12-26  258.396667  259.474086  257.010028  257.568678  27237100
# 2024-12-27  254.974930  258.077462  252.451019  257.209530  42355300
# 2024-12-30  251.593094  252.889969  250.146586  251.623020  35557500
# 2024-12-31  249.817383  252.670501  248.829760  251.832526  39480700
#
# Price             RSI      MACD Signal Line Rolling Mean Rolling Std  \
# Ticker
# Date
# 2024-12-24  75.750273  6.059382    5.383118   245.700803    6.532681
# 2024-12-26  76.452865  6.291770    5.564848   246.895920    6.560954
# 2024-12-27  67.626263  6.129180    5.677715   247.926434    6.090868
# 2024-12-30  60.225588  5.662171    5.674606   248.668144    5.537443
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# Prepare data for Regression
# Combine features and target to drop NaNs consistently
data_reg = data.copy()
data_reg['Target_Close'] = data_reg['Close'] # Use a temporary column for the target

# Features are all columns except the temporary target
X = data_reg.drop(['Close', 'Target_Close'], axis=1)
y = data_reg['Target_Close']

# Drop NaNs from the combined data
combined_data_reg = pd.concat([X, y], axis=1).dropna()
X = combined_data_reg.drop('Target_Close', axis=1)
y = combined_data_reg['Target_Close']

# Split data for Regression
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print("Regression Data Shapes:")
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

# Train Linear Regression Model
linear_reg_model = LinearRegression()
linear_reg_model.fit(X_train, y_train)

# Prepare data for Classification
# Create binary target variable: 1 if next day's closing price is higher, 0 other
data_cls = data.copy()
data_cls['Price_Change'] = data_cls['Close'].pct_change().shift(-1)
data_cls['Target_Classification'] = np.where(data_cls['Price_Change'] > 0, 1, 0) # Remove dropna() here

# Features (X_cls) are all columns except the targets and future price change
X_cls = data_cls.drop(['Close', 'Price_Change', 'Target_Classification'], axis=1)
y_cls = data_cls['Target_Classification']

# Drop NaNs from the combined data for classification
combined_data_cls = pd.concat([X_cls, y_cls], axis=1).dropna()
X_cls = combined_data_cls.drop('Target_Classification', axis=1)
y_cls = combined_data_cls['Target_Classification']


# Split data for Classification
X_train_cls, X_test_cls, y_train_cls, y_test_cls = train_test_split(X_cls, y_cls, test_size=0.3, random_state=42)

print("\nClassification Data Shapes:")
print("X_train_cls shape:", X_train_cls.shape)
print("X_test_cls shape:", X_test_cls.shape)
print("y_train_cls shape:", y_train_cls.shape)
print("y_test_cls shape:", y_test_cls.shape)


# Train Random Forest Classifier Model
random_forest_model = RandomForestClassifier(random_state=42)
random_forest_model.fit(X_train_cls, y_train_cls)
# Out:
# Regression Data Shapes:
# X_train shape: (867, 12)
# X_test shape: (372, 12)
# y_train shape: (867,)
# y_test shape: (372,)
#
# Classification Data Shapes:
# X_train_cls shape: (867, 12)
# X_test_cls shape: (372, 12)
# y_train_cls shape: (867,)
# y_test_cls shape: (372,)
# RandomForestClassifier(random_state=42)

# %% [markdown]
# # Task
# Use the existing AAPL dataset covering 2020-01-01 to 2025-01-01.
#
# 1. Split the dataset so that:
#    - Training/testing for model evaluation uses only data from 2020-01-01 to 2023-01-01.
#    - Data from 2023-01-02 to 2025-08-11 is reserved for forecasting.
#
# 2. For the training/testing subset:
#    - Keep the 70/30 train-test split with random_state=42.
#    - Evaluate the Linear Regression model (price prediction) using:
#      * R² score
#      * Mean Absolute Error (MAE)
#      * Root Mean Squared Error (RMSE)
#      * Predicted vs Actual price plot
#    - Evaluate the Random Forest Classifier (trend prediction) using:
#      * Classification report
#      * Confusion matrix
#      * Accuracy score
#
# 3. For the forecasting subset (2023-2025):
#    - Use both trained models to generate predictions.
#    - For the regression model, plot predicted vs actual prices for this period.
#    - For the classification model, show predicted "up" or "down" trends.
#
# 4. Return clean, runnable Python code with all necessary imports and variable definitions, and display all evaluation metrics and plots.

# %% [markdown]
# ## Data preparation for evaluation and forecasting
#
# ### Subtask:
# Split the original `data` DataFrame into two subsets based on the specified date ranges: one for model evaluation (2020-01-01 to 2023-01-01) and another for forecasting (2023-01-02 to 2025-08-11).

# %% [markdown]
# **Reasoning**:
# Split the data into evaluation and forecasting sets based on the specified date ranges and display the shapes of the resulting dataframes.

# %%
# Define the end date for the evaluation data
evaluation_end_date = '2023-01-01'

# Create evaluation_data by filtering the original data
evaluation_data = data[data.index <= evaluation_end_date].copy()

# Define the start and end dates for the forecasting data
forecasting_start_date = '2023-01-02'
forecasting_end_date = '2025-08-11'

# Create forecasting_data by filtering the original data
forecasting_data = data[(data.index >= forecasting_start_date) & (data.index <= forecasting_end_date)].copy()

# Display the shapes of the resulting dataframes
print("Shape of evaluation_data:", evaluation_data.shape)
print("Shape of forecasting_data:", forecasting_data.shape)
# Out:
# Shape of evaluation_data: (756, 13)
# Shape of forecasting_data: (502, 13)

# %% [markdown]
# ## Prepare evaluation data
#
# ### Subtask:
# From the evaluation subset, create feature (X_eval) and target (y_eval) variables for both regression and classification tasks, handling NaNs consistently. Split this evaluation data into 70/30 train-test sets with `random_state=42`.

# %% [markdown]
# **Reasoning**:
# Prepare the evaluation data for both regression and classification tasks by creating feature and target variables and splitting them into training and testing sets.

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# Prepare data for Regression
# Create a copy for regression task
evaluation_data_reg = evaluation_data.copy()
# Create a temporary target column for regression
evaluation_data_reg['Target_Close'] = evaluation_data_reg['Close']

# Define features (X_eval_reg) by dropping 'Close' and the temporary target
X_eval_reg = evaluation_data_reg.drop(['Close', 'Target_Close'], axis=1)
# Define target (y_eval_reg)
y_eval_reg = evaluation_data_reg['Target_Close']

# Combine to drop NaNs consistently
combined_eval_reg = pd.concat([X_eval_reg, y_eval_reg], axis=1).dropna()
X_eval_reg = combined_eval_reg.drop('Target_Close', axis=1)
y_eval_reg = combined_eval_reg['Target_Close']

# Split data for Regression
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(X_eval_reg, y_eval_reg, test_size=0.3, random_state=42)

# Prepare data for Classification
# Create a copy for classification task
evaluation_data_cls = evaluation_data.copy()
# Calculate binary target variable for classification
evaluation_data_cls['Price_Change'] = evaluation_data_cls['Close'].pct_change().shift(-1)
evaluation_data_cls['Target_Classification'] = np.where(evaluation_data_cls['Price_Change'] > 0, 1, 0)

# Define features (X_eval_cls) by dropping 'Close', 'Price_Change', and the target
X_eval_cls = evaluation_data_cls.drop(['Close', 'Price_Change', 'Target_Classification'], axis=1)
y_eval_cls = evaluation_data_cls['Target_Classification']

# Combine to drop NaNs consistently
combined_eval_cls = pd.concat([X_eval_cls, y_eval_cls], axis=1).dropna()
X_eval_cls = combined_eval_cls.drop('Target_Classification', axis=1)
y_eval_cls = combined_eval_cls['Target_Classification']

# Print the shapes of the resulting datasets
print("Regression Data Shapes:")
print("X_train_reg shape:", X_train_reg.shape)
print("X_test_reg shape:", X_test_reg.shape)
print("y_train_reg shape:", y_train_reg.shape)
print("y_test_reg shape:", y_test_reg.shape)

print("\nClassification Data Shapes:")
print("X_train_cls shape:", X_train_cls.shape)
print("X_test_cls shape:", X_test_cls.shape)
print("y_train_cls shape:", y_train_cls.shape)
print("y_test_cls shape:", y_test_cls.shape)
# Out:
# Regression Data Shapes:
# X_train_reg shape: (515, 12)
# X_test_reg shape: (222, 12)
# y_train_reg shape: (515,)
# y_test_reg shape: (222,)
#
# Classification Data Shapes:
# X_train_cls shape: (867, 12)
# X_test_cls shape: (372, 12)
# y_train_cls shape: (867,)
# y_test_cls shape: (372,)

# %% [markdown]
# **Reasoning**:
# The previous code failed because the column names in the `evaluation_data` DataFrame are MultiIndex tuples, not simple strings like ('Price', 'Close'). I need to access the columns using the correct MultiIndex keys. The previous code block also already included the necessary imports, so I don't need to import them again.

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import numpy as np

# Make predictions on the regression test set
y_pred_reg = linear_reg_model.predict(X_test_reg)

# Calculate evaluation metrics
r2 = r2_score(y_test_reg, y_pred_reg)
mae = mean_absolute_error(y_test_reg, y_pred_reg)
mse = mean_squared_error(y_test_reg, y_pred_reg)
rmse = np.sqrt(mse) # Calculate RMSE by taking the square root of MSE

# Display the evaluation metrics
print("Linear Regression Model Evaluation:")
print(f"R² Score: {r2:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

# Plot Predicted vs Actual Prices
plt.figure(figsize=(12, 6))
plt.scatter(y_test_reg.index, y_test_reg, color='blue', label='Actual Price', alpha=0.6)
plt.scatter(y_test_reg.index, y_pred_reg, color='red', label='Predicted Price', alpha=0.6)
plt.title('Linear Regression: Actual vs Predicted Prices (Evaluation Set)')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Linear Regression Model Evaluation:
# R² Score: 0.9993
# Mean Absolute Error (MAE): 0.5815
# Root Mean Squared Error (RMSE): 0.7856

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# Make predictions on the classification test set
y_pred_cls = random_forest_model.predict(X_test_cls)

# Display evaluation metrics
print("Random Forest Classifier Evaluation:")
print("\nClassification Report:")
print(classification_report(y_test_cls, y_pred_cls))

print("\nConfusion Matrix:")
cm = confusion_matrix(y_test_cls, y_pred_cls)
print(cm)

print("\nAccuracy Score:")
print(accuracy_score(y_test_cls, y_pred_cls))

# Optional: Visualize Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix (Evaluation Set)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Random Forest Classifier Evaluation:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.42      0.49      0.46       165
#            1       0.54      0.47      0.50       207
#
#     accuracy                           0.48       372
#    macro avg       0.48      0.48      0.48       372
# weighted avg       0.49      0.48      0.48       372
#
#
# Confusion Matrix:
# [[ 81  84]
#  [110  97]]
#
# Accuracy Score:
# 0.478494623655914

# %%
# Prepare data for Forecasting

# For Regression Forecasting:
# Select features and target from forecasting_data, handling MultiIndex and top-level columns
# Assuming features are all columns EXCEPT the 'Close' price column
feature_columns_reg = [col for col in forecasting_data.columns if col != 'Close']
target_column_reg = 'Close'

X_forecast_reg = forecasting_data[feature_columns_reg].copy()
y_forecast_reg = forecasting_data[target_column_reg].copy()

# Combine features and target to drop NaNs consistently for regression forecasting
combined_forecast_reg = pd.concat([X_forecast_reg, y_forecast_reg], axis=1).dropna()
X_forecast_reg = combined_forecast_reg[feature_columns_reg] # Select features again after dropping NaNs
y_forecast_reg = combined_forecast_reg['AAPL'] # Access target using the correct column name 'AAPL'


# For Classification Forecasting:
# Create binary target variable: 1 if next day's closing price is higher, 0 other
forecasting_data_cls = forecasting_data.copy()
forecasting_data_cls['Price_Change'] = forecasting_data_cls['Close'].pct_change().shift(-1)
forecasting_data_cls['Target_Classification'] = np.where(forecasting_data_cls['Price_Change'] > 0, 1, 0)

# Features (X_forecast_cls) are all columns except the targets and future price change
X_forecast_cls = forecasting_data_cls.drop(['Close', 'Price_Change', 'Target_Classification'], axis=1)
y_forecast_cls = forecasting_data_cls['Target_Classification']

# Drop NaNs from the combined data for classification forecasting
combined_forecast_cls = pd.concat([X_forecast_cls, y_forecast_cls], axis=1).dropna()
X_forecast_cls = combined_forecast_cls.drop('Target_Classification', axis=1)
y_forecast_cls = combined_forecast_cls['Target_Classification']


# Print the shapes of the resulting datasets
print("Forecasting Data Shapes (Regression):")
print("X_forecast_reg shape:", X_forecast_reg.shape)
print("y_forecast_reg shape:", y_forecast_reg.shape)

print("\nForecasting Data Shapes (Classification):")
print("X_forecast_cls shape:", X_forecast_cls.shape)
print("y_forecast_cls shape:", y_forecast_cls.shape)
# Out:
# Forecasting Data Shapes (Regression):
# X_forecast_reg shape: (502, 13)
# y_forecast_reg shape: (502,)
#
# Forecasting Data Shapes (Classification):
# X_forecast_cls shape: (502, 12)
# y_forecast_cls shape: (502,)

# %%
import matplotlib.pyplot as plt

# Ensure forecasting features have the same columns as training features
X_forecast_reg = X_forecast_reg[X_train_reg.columns]

# Generate regression predictions for the forecasting period
y_forecast_pred_reg = linear_reg_model.predict(X_forecast_reg)

# Plot Predicted vs Actual Prices for Forecasting Period
plt.figure(figsize=(12, 6))
plt.plot(y_forecast_reg.index, y_forecast_reg, color='blue', label='Actual Price', alpha=0.6)
plt.plot(y_forecast_reg.index, y_forecast_pred_reg, color='red', label='Predicted Price', alpha=0.6)
plt.title('Linear Regression: Actual vs Predicted Prices (Forecasting Period)')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Ensure forecasting features for classification have the same columns as training features
X_forecast_cls = X_forecast_cls[X_train_cls.columns]

# Generate classification predictions for the forecasting period
y_forecast_pred_cls = random_forest_model.predict(X_forecast_cls)

# Display the predicted trends
print("Random Forest Classifier Predicted Trends (Forecasting Period):")
# Map predictions back to 'Up' (1) and 'Down' (0) for better readability
predicted_trends = pd.Series(y_forecast_pred_cls, index=X_forecast_cls.index).map({1: 'Up', 0: 'Down'})
display(predicted_trends)
# Out:
# Random Forest Classifier Predicted Trends (Forecasting Period):
# Date
# 2023-01-03      Up
# 2023-01-04      Up
# 2023-01-05      Up
# 2023-01-06      Up
# 2023-01-09      Up
#               ...
# 2024-12-24    Down
# 2024-12-26    Down
# 2024-12-27    Down
# 2024-12-30    Down
# 2024-12-31    Down
# Length: 502, dtype: object

# %% [markdown]
# Using the model evaluation results: Linear Regression (Price Prediction): - R²: 0.9993 - MAE: 0.5815 - RMSE: 0.7856 - Very close predicted vs actual alignment in historical data but noticeable deviations in 2023–2025 forecasts, especially during volatile periods. Random Forest Classifier (Trend Prediction): - Accuracy: 0.4785 - Classification metrics show low precision, recall, and f1-scores for both classes. - Forecasted trends for 2023–2025 should be interpreted with caution. Based on this, provide: 1. Two potential trading strategies — one using the regression predictions and one using the classification predictions. 2. A discussion of the risks, including overfitting, volatility, and the limitations of historical-data-based forecasting. 3. A critical evaluation of whether either model is actually suitable for real-world trading. 4. Suggestions for improving predictive performance in future iterations. Write the response in clear, concise paragraphs suitable for an academic assignment, without excessive technical jargon.
# Based on the model evaluation results, let's discuss potential trading strategies, associated risks, the models' suitability for real-world trading, and avenues for improvement.
#
# Potential Trading Strategies
#
# Given the performance of the models, two potential, albeit cautious, trading strategies could be considered:
#
# Regression-Based Strategy (Price Following): Although the regression model shows deviations in forecasting, its strong performance on historical data suggests it captures the general price movement well within that period. A strategy could involve using the regression model to identify periods where the predicted price shows a clear upward trend. During such periods, one might consider buying with tight stop-loss orders to limit potential losses if the price deviates significantly from the prediction. This strategy relies on the assumption that historical patterns of price movement captured by the model might continue to some extent, but the observed forecasting deviations highlight the need for caution and risk management.
# Classification-Based Strategy (Confirmation Signal): The Random Forest Classifier's low accuracy indicates it's not reliable for making direct buy/sell decisions based solely on its trend predictions. However, in a highly conservative approach, one might consider using the model's "Up" prediction as a secondary confirmation signal in conjunction with other, more reliable indicators or analysis methods. For instance, if other technical or fundamental analysis strongly suggests an upward movement, and the Random Forest model also predicts "Up," it might provide a weak added layer of conviction. This strategy acknowledges the model's limitations and avoids relying on its predictions as the primary trading signal.
# Discussion of Risks
#
# Several significant risks are associated with using these models for stock price forecasting and trading:
#
# Overfitting: The very high R² score of the Linear Regression model on the historical evaluation data (0.9993) strongly suggests overfitting. Overfitting occurs when a model learns the training data too well, capturing noise and random fluctuations rather than the underlying patterns. This leads to excellent performance on the data it was trained on but poor performance on new, unseen data, as evidenced by the noticeable deviations in the 2023-2025 forecasts.
# Volatility: Stock markets are inherently volatile, meaning prices can change rapidly and unpredictably due to numerous factors including news events, economic data, and market sentiment. Models trained on historical data may struggle to account for sudden shifts or Black Swan events that were not present in the training set. The deviations in the regression forecasts during volatile periods illustrate this risk.
# Limitations of Historical Data-Based Forecasting: Stock prices are influenced by a vast and complex array of factors, many of which are not captured in historical price and volume data or the technical indicators derived from them. These include company-specific news, industry trends, macroeconomic conditions, geopolitical events, and investor psychology. Relying solely on models trained on historical data without incorporating these external factors inherently limits their predictive power for the future.
# Critical Evaluation of Suitability for Real-World Trading
#
# Based on the evaluation results, neither model, in their current form, appears suitable for real-world trading:
#
# The Linear Regression model, despite its impressive fit on historical data, is likely overfitted. Its inability to accurately forecast prices in the 2023-2025 period indicates it cannot reliably predict future price movements. Trading based on potentially overfitted predictions would be highly risky.
# The Random Forest Classifier's accuracy close to 50% means its trend predictions are essentially random guesses. Using such a model for trading decisions would be equivalent to flipping a coin.
# Therefore, neither model demonstrates the necessary predictive accuracy or reliability to be used for making actual trading decisions in a real-world financial market.
#
# Suggestions for Improving Predictive Performance
#
# To improve predictive performance in future iterations, consider the following:
#
# Advanced Feature Engineering: Explore a wider range of technical indicators and create features that capture market sentiment (e.g., from news or social media) and relevant economic indicators.
# More Robust Models: Experiment with more complex and potentially more powerful models, such as time series models (e.g., ARIMA, LSTM neural networks), or other ensemble methods, which may be better equipped to handle sequential data like stock prices.
# Regularization Techniques: Implement regularization techniques (e.g., L1 or L2 regularization in linear models, or tuning hyperparameters in tree-based models) during training to mitigate overfitting.
# Cross-Validation: Use time-series cross-validation techniques during model training and evaluation to get a more realistic estimate of how the model will perform on unseen data.
# Incorporate External Data: Include fundamental data about the company (earnings, valuations), industry analysis, and macroeconomic data as features.
# By addressing these areas, the predictive performance of the models could potentially be improved, although the inherent difficulty of stock market prediction will always remain a significant challenge.
